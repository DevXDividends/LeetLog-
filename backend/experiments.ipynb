# %%
from github import Auth,Github
import os 
import json
from dotenv import load_dotenv
load_dotenv() # load github token
# Out:
# True

# %%
token = os.getenv("Github_access_token")
if token:
    print(True)
# Out:
# True

# %%
auth = Auth.Token(
    token=token
)

# %%
g = Github(
    auth=auth
)

# %%
user = g.get_user()

# %%
repo = user.get_repos()

# %%
for rep in repo:
    print(rep)
# Out:
# Repository(full_name="DevXDividends/Arogyam-Agentic-AI-for-medical-imaging-and-diagnosis")
# Repository(full_name="DevXDividends/CodeForge-RCE")
# Repository(full_name="DevXDividends/D.S.A")
# Repository(full_name="DevXDividends/DevXDividends")
# Repository(full_name="DevXDividends/docker-react")
# Repository(full_name="DevXDividends/HERMES-Hidden-and-Encrypted-Recursive-Media-Encoding-System")
# Repository(full_name="DevXDividends/Hospital-Managment-System")
# Repository(full_name="DevXDividends/K-Map-visualiser")
# Repository(full_name="DevXDividends/LanShare")
# Repository(full_name="DevXDividends/LanShareCPP")
# Repository(full_name="DevXDividends/LeetLog-")
# Repository(full_name="DevXDividends/QEMS-system")
# Repository(full_name="DevXDividends/Resume-Checker")
# Repository(full_name="DevXDividends/Text-to-voice-converter")
# Repository(full_name="DevXDividends/Travel-Planner-Using-Dijkstra-s-algorithm")
# Repository(full_name="DevXDividends/Typing-speed-test")
# Repository(full_name="kartikpagariya25/HERMES-Hidden-and-Encrypted-Recursive-Media-Encoding-System")
# Repository(full_name="kartikpagariya25/XAI-Heart-Disease-Prediction")
# Repository(full_name="VikrantKadam028/CardioXAI")
# Repository(full_name="VikrantKadam028/MailJi")

# %%
repo = g.get_repo("DevXDividends/D.S.A")

# %%
dsa_repo = repo.get_contents("")

# %%
dsa_repo
# Out:
# [ContentFile(path="Binary Search"),
#  ContentFile(path="Linked List"),
#  ContentFile(path="README.md"),
#  ContentFile(path="Recursion"),
#  ContentFile(path="Sliding window & Two Pointers"),
#  ContentFile(path="Stack"),
#  ContentFile(path="Strings"),
#  ContentFile(path="Tree"),
#  ContentFile(path="Two Pointer"),
#  ContentFile(path="arrays")]

# %%
data = {}
cnt = 0
for item in dsa_repo:
    if item.type == "dir":
        print(f"\n📂 Entering Folder: {item.name}")
         # Create folder key
        data[item.name] = {}
        folder_contents = repo.get_contents(item.path)
        # print(folder_contents)
        for item_file in folder_contents:
            if item_file.type == "file":
                cnt = cnt+1
                print(f" 📄 File: {item_file.name}")
                code  = item_file.decoded_content.decode("utf-8")
                data[item.name][item_file.name] = code
                preview = "\n".join(code.splitlines()[:3])
                print(f"    Code Preview:\n{preview}\n    ...")
# Out:
# 📂 Entering Folder: Binary Search
#  📄 File: Aggressive-cows.cpp
#     Code Preview:
#  //Brute force TC: O(n×maxDist) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Allocate-Minimum-Pages.cpp
#     Code Preview:
# //Brute force TC:O(n  * sum(arr)  - max(arr)) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Count of Smaller Numbers After Self.cpp
#     Code Preview:
# // brute force TC:O(n^2) SC:O(n)
# class Solution {
# public:
#     ...
#  📄 File: Find Right Interval.cpp
#     Code Preview:
# // Brute force TC:O(n² + n log n + n) SC:O(3n)
# class Solution {
# public:
#     ...
#  📄 File: Find Smallest Letter Greater Than Target.cpp
#     Code Preview:
# // TC:O(log n) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Find a Peak Element II.cpp
#     Code Preview:
# // brute force TC:O(rows * cols) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Find the Duplicate Number.cpp
#     Code Preview:
# // brute force TC:o(n) SC:O(n)
# class Solution {
# public:
#     ...
#  📄 File: Find-Minimum-in-Rotated-Sorted-Array-II.cpp
#     Code Preview:
# // Brute approach : TC:O(n) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: First and Last Occurrences.cpp
#     Code Preview:
# // TC:O(log n) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: First-Bad-Version.cpp
#     Code Preview:
# // The API isBadVersion is defined for you.
# // bool isBadVersion(int version);
#
#     ...
#  📄 File: H-Index II.cpp
#     Code Preview:
# // TC:O(log n) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Heaters.cpp
#     Code Preview:
# // TC:O(n × log m) SC:So = O(1)
# class Solution {
# public:
#     ...
#  📄 File: Intersection-of-Two-Arrays.cpp
#     Code Preview:
# class Solution {
# public:
#     vector<int> intersection(vector<int>& nums1, vector<int>& nums2) {
#     ...
#  📄 File: K-diff Pairs in an Array.cpp
#     Code Preview:
# // TC:O(n^2) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: K-th element of two Arrays.cpp
#     Code Preview:
# brute TC:O(a) + O(b) + O(n log n) SC:O(a+b)
#   class Solution {
#   public:
#     ...
#  📄 File: Kth Smallest Element in a Sorted Matrix.cpp
#     Code Preview:
# // TC:O(n · log(maxValue)) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Kth Smallest Product of Two Sorted Arrays.cpp
#     Code Preview:
#  // brute force approach TC:O(n1 × n2 log(n1 × n2)) SC:O(nums1 * nums2)
# class Solution {
# public:
#     ...
#  📄 File: Kth-Missing-Positive-Number.cpp
#     Code Preview:
# // Brute force approach TC: O(n)  SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Median in a row-wise sorted Matrix.cpp
#     Code Preview:
# // TC:O(n × m × log(n × m)) SC:O(n × m)
# class Solution {
#   public:
#     ...
#  📄 File: Median-of-Two-Sorted-Arrays.cpp
#     Code Preview:
# class Solution {
# public:
#     double findMedianSortedArrays(vector<int>& nums1, vector<int>& nums2) {
#     ...
#  📄 File: Minimize Max Distance to Gas Station.cpp
#     Code Preview:
#  // brute TC:O(k*n) + O(n)
# class Solution {
# public:
#     ...
#  📄 File: Minimum Size Subarray Sum.cpp
#     Code Preview:
# // TC:O(n^3) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Nim game.cpp
#     Code Preview:
# class Solution {
# public:
#     bool canWinNim(int n) {
#     ...
#  📄 File: Number of occurrence.cpp
#     Code Preview:
# // TC:O(log n) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Row With Maximum Ones.cpp
#     Code Preview:
# // brute TC:O(rows * cols) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Search a 2D Matrix.cpp
#     Code Preview:
# // brute TC:O(rows * cols)  SC:(1)
# class Solution {
# public:
#     ...
#  📄 File: Search in Rotated Sorted Array.cpp
#     Code Preview:
# // TC:PO(log n) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Search-Insert-Position.cpp
#     Code Preview:
# class Solution {
#     public int searchInsert(int[] nums, int target) {
#         int low=0,high=nums.length-1;
#     ...
#  📄 File: Split-Array-Largest-Sum.cpp
#     Code Preview:
#  // Brute force TC: O(n * maxLimit - minLimit )SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Sqrt(x).cpp
#     Code Preview:
# class Solution {
# public:
#     int mySqrt(int x) {
#     ...
#
# 📂 Entering Folder: Linked List
#  📄 File: Add Number Linked Lists.cpp
#     Code Preview:
# // TC:O(m + n) SC:O(max(n, m))
# /*
# class Node {
#     ...
#  📄 File: Add one to a linked list number.cpp
#     Code Preview:
# // TC:O(3n) SC:O(1)
# /*
#
#     ...
#  📄 File: Convert Binary Number in a Linked List to Integer.cpp
#     Code Preview:
# // TC :O(n) SC:O(n)
# class Solution {
# public:
#     ...
#  📄 File: Copy List with Random Pointer.cpp
#     Code Preview:
# // brute force TC:O(n) SC:O(n)
# /*
# // Definition for a Node.
#     ...
#  📄 File: Delete N nodes after M nodes of a linked list.cpp
#     Code Preview:
# // TC:O(n) SC:O(1)
# /*
# delete n nodes after m nodes
#     ...
#  📄 File: Double a Number Represented as a Linked List.cpp
#     Code Preview:
# // brute TC:O(n) SC:O(n)
# /**
#  * Definition for singly-linked list.
#     ...
#  📄 File: Find k th node in Linked list.cpp
#     Code Preview:
# //TC:O(n) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Find length of Loop.cpp
#     Code Preview:
# // TC:O(n) SC:O(n)
# /*
# class Node {
#     ...
#  📄 File: Flatten Binary Tree to Linked List.cpp
#     Code Preview:
# brute TC:O(n) SC:O(n)
# class Solution {
# public:
#     ...
#  📄 File: Flattening a Linked List.cpp
#     Code Preview:
# // TC:O(n * k) SC:O(1)
# /*
# class Node {
#     ...
#  📄 File: Intersection of 2 linked list.cpp
#     Code Preview:
# // TC:o(m+n) SC:O(m)
# /**
#  * Definition for singly-linked list.
#     ...
#  📄 File: Linked List Cycle II.cpp
#     Code Preview:
# // TC:O(n) SC:O(n)
# /**
#  * Definition for singly-linked list.
#     ...
#  📄 File: Linked List Random Node.cpp
#     Code Preview:
# // brute TC:O(1) SC:O(n)
# /**
#  * Definition for singly-linked list.
#     ...
#  📄 File: Merge 2 sorted linked list in reverse order.cpp
#     Code Preview:
# // Brute Force
# // TC = O(k log k) SC = O(k)
# class Solution {
#     ...
#  📄 File: Merge k Sorted Lists.cpp
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File C:\Program Files\Python312\Lib\socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     758 sock: socket.socket | ssl.SSLSocket
# --> 759 self.sock = sock = self._new_conn()
#     760 server_hostname: str = self.host
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connection.py:211, in HTTPConnection._new_conn(self)
#     210 except socket.gaierror as e:
# --> 211     raise NameResolutionError(self.host, self, e) from e
#     212 except SocketTimeout as e:
#
# NameResolutionError: HTTPSConnection(host='api.github.com', port=443): Failed to resolve 'api.github.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:872, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869     log.warning(
#     870         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     871     )
# --> 872     return self.urlopen(
#     873         method,
#     874         url,
#     875         body,
#     876         headers,
#     877         retries,
#     878         redirect,
#     879         assert_same_host,
#     880         timeout=timeout,
#     881         pool_timeout=pool_timeout,
#     882         release_conn=release_conn,
#     883         chunked=chunked,
#     884         body_pos=body_pos,
#     885         preload_content=preload_content,
#     886         decode_content=decode_content,
#     887         **response_kw,
#     888     )
#     890 # Handle redirect?
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:872, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869     log.warning(
#     870         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     871     )
# --> 872     return self.urlopen(
#     873         method,
#     874         url,
#     875         body,
#     876         headers,
#     877         retries,
#     878         redirect,
#     879         assert_same_host,
#     880         timeout=timeout,
#     881         pool_timeout=pool_timeout,
#     882         release_conn=release_conn,
#     883         chunked=chunked,
#     884         body_pos=body_pos,
#     885         preload_content=preload_content,
#     886         decode_content=decode_content,
#     887         **response_kw,
#     888     )
#     890 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 872 (7 times)]
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:872, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869     log.warning(
#     870         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     871     )
# --> 872     return self.urlopen(
#     873         method,
#     874         url,
#     875         body,
#     876         headers,
#     877         retries,
#     878         redirect,
#     879         assert_same_host,
#     880         timeout=timeout,
#     881         pool_timeout=pool_timeout,
#     882         release_conn=release_conn,
#     883         chunked=chunked,
#     884         body_pos=body_pos,
#     885         preload_content=preload_content,
#     886         decode_content=decode_content,
#     887         **response_kw,
#     888     )
#     890 # Handle redirect?
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\GithubRetry.py:208, in GithubRetry.increment(self, method, url, response, error, _pool, _stacktrace)
#     207 # retry the request as usual
# --> 208 return super().increment(method, url, response, error, _pool, _stacktrace)
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\urllib3\util\retry.py:543, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     542     reason = error or ResponseError(cause)
# --> 543     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     545 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/DevXDividends/D.S.A/contents/Linked%20List/Merge%20k%20Sorted%20Lists.cpp?ref=main (Caused by NameResolutionError("HTTPSConnection(host='api.github.com', port=443): Failed to resolve 'api.github.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[11], line 14
#      10         for item_file in folder_contents:
#      11             if item_file.type == "file":
#      12                 cnt = cnt+1
#      13                 print(f" 📄 File: {item_file.name}")
# ---> 14                 code  = item_file.decoded_content.decode("utf-8")
#      15                 data[item.name][item_file.name] = code
#      16                 preview = "\n".join(code.splitlines()[:3])
#      17                 print(f"    Code Preview:\n{preview}\n    ...")
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\ContentFile.py:125, in ContentFile.decoded_content(self)
#     123 @property
#     124 def decoded_content(self) -> bytes:
# --> 125     assert self.encoding == "base64", f"unsupported encoding: {self.encoding}"
#     126     return base64.b64decode(bytearray(self.content, "utf-8"))
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\ContentFile.py:135, in ContentFile.encoding(self)
#     133 @property
#     134 def encoding(self) -> str:
# --> 135     self._completeIfNotSet(self._encoding)
#     136     return self._encoding.value
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\GithubObject.py:620, in CompletableGithubObject._completeIfNotSet(self, value)
#     618 def _completeIfNotSet(self, value: Attribute) -> None:
#     619     if isinstance(value, _NotSetType):
# --> 620         self._completeIfNeeded()
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\GithubObject.py:624, in CompletableGithubObject._completeIfNeeded(self)
#     622 def _completeIfNeeded(self) -> None:
#     623     if not self.__completed:
# --> 624         self._complete()
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\GithubObject.py:629, in CompletableGithubObject._complete(self, parameters)
#     627 if self._url.value is None:
#     628     raise IncompletableObject(400, message="Cannot complete object as it contains no URL")
# --> 629 headers, data = self._requester.requestJsonAndCheck(
#     630     "GET", self._url.value, parameters=parameters, headers=self.__completeHeaders
#     631 )
#     632 self._storeAndUseAttributes(headers, data)
#     633 self._set_complete()
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\Requester.py:629, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input, follow_302_redirect)
#     607 def requestJsonAndCheck(
#     608     self,
#     609     verb: str,
#    (...)    614     follow_302_redirect: bool = False,
#     615 ) -> tuple[dict[str, Any], Any]:
#     616     """
#     617     Send a request with JSON body.
#     618
#    (...)    623
#     624     """
#     625     return self.__postProcess(
#     626         verb,
#     627         url,
#     628         *self.__check(
# --> 629             *self.requestJson(
#     630                 verb,
#     631                 url,
#     632                 parameters,
#     633                 headers,
#     634                 input,
#     635                 self.__customConnection(url),
#     636                 follow_302_redirect=follow_302_redirect,
#     637             )
#     638         ),
#     639     )
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\Requester.py:1073, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx, follow_302_redirect)
#    1070 def encode(input: Any) -> tuple[str, str]:
#    1071     return "application/json", json.dumps(input)
# -> 1073 status, responseHeaders, output = self.__requestEncode(
#    1074     cnx, verb, url, parameters, headers, input, encode, follow_302_redirect=follow_302_redirect
#    1075 )
#    1076 if isinstance(output, str):
#    1077     return status, responseHeaders, output
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\Requester.py:1212, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode, stream, follow_302_redirect)
#    1208     requestHeaders["Content-Type"], encoded_input = encode(input)
#    1210 self.NEW_DEBUG_FRAME(requestHeaders)
# -> 1212 status, responseHeaders, output = self.__requestRaw(
#    1213     cnx, verb, url, requestHeaders, encoded_input, stream=stream, follow_302_redirect=follow_302_redirect
#    1214 )
#    1216 if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#    1217     self.rate_limiting = (
#    1218         # ints expected but sometimes floats returned: https://github.com/PyGithub/PyGithub/pull/2697
#    1219         int(float(responseHeaders[Consts.headerRateRemaining])),
#    1220         int(float(responseHeaders[Consts.headerRateLimit])),
#    1221     )
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\Requester.py:1250, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input, stream, follow_302_redirect)
#    1248     cnx = self.__createConnection()
#    1249 cnx.request(verb, url, input, requestHeaders, stream)
# -> 1250 response = cnx.getresponse()
#    1251 output = response if stream else response.read()
#    1252 status = response.status
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\github\Requester.py:206, in HTTPSRequestsConnectionClass.getresponse(self)
#     204 verb = getattr(self.session, self.verb.lower())
#     205 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 206 r = verb(
#     207     url,
#     208     headers=self.headers,
#     209     data=self.input,
#     210     timeout=self.timeout,
#     211     verify=self.verify,
#     212     allow_redirects=False,
#     213 )
#     214 return RequestsResponse(r)
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\requests\sessions.py:671, in Session.get(self, url, params, **kwargs)
#     661 r"""Sends a GET request. Returns :class:`Response` object.
#     662
#     663 :param url: URL for the new :class:`Request` object.
#    (...)    667 :rtype: requests.Response
#     668 """
#     670 kwargs.setdefault("allow_redirects", True)
# --> 671 return self.request("GET", url, params=params, **kwargs)
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File d:\Aditya\LeetLog-\backend\venv\Lib\site-packages\requests\adapters.py:729, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     725     if isinstance(e.reason, _SSLError):
#     726         # This branch is for urllib3 v1.22 and later.
#     727         raise SSLError(e, request=request)
# --> 729     raise ConnectionError(e, request=request)
#     731 except ClosedPoolError as e:
#     732     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/DevXDividends/D.S.A/contents/Linked%20List/Merge%20k%20Sorted%20Lists.cpp?ref=main (Caused by NameResolutionError("HTTPSConnection(host='api.github.com', port=443): Failed to resolve 'api.github.com' ([Errno 11001] getaddrinfo failed)"))

# %%
cnt

# %%
with open("dsa_data.json",'w',encoding="utf-8") as file:
    json.dump(data,file,indent=4,ensure_ascii=False)
print("All data saved !")

# %%
print(data["Stack"]["Largest Rectangle in Histogram.cpp"])

# %%
with open("dsa_data.json",'r',encoding="utf-8") as file:
    d = json.load(file)

# %%
type(d)

# %%
with open("dsa_descriptions.json",'r')as file:
    des = json.load(file)

# %%
des["Aggressive-cows.cpp"].keys()

# %%
print(des["Aggressive-cows.cpp"]["title"])
print(des["Aggressive-cows.cpp"]["source"])
print(des["Aggressive-cows.cpp"]["description"])
print(des["Aggressive-cows.cpp"]["examples"])

# %%
def get_problem_metadata(des,problem):
    if problem in des:
        return{
            "title": des[problem]["title"],
            "source":des[problem]["source"],
            "description":des[problem]["description"],
            "examples":des[problem]["examples"],
            "link":des[problem]["link"]
        }
    else:
        return {
            "title": "No data Found !"
        }

# %%
problem = "Allocate-Minimum-Pages.cpp"
get_problem_metadata(des,problem=problem)
