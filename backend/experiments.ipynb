# %%
from github import Auth,Github
import os 
import json
import psycopg
from psycopg.rows import dict_row
from dotenv import load_dotenv
load_dotenv() # load github token
# Out:
# True

# %%
conn = psycopg.connect(
    dbname = "leetlog",
    user= "postgres",
    password = "root",
    host = "localhost",
    row_factory=dict_row
)

# %%
cur = conn.cursor()

# %%
token = os.getenv("Github_access_token")
if token:
    print(True)
# Out:
# True

# %%
auth = Auth.Token(
    token=token
)

# %%
g = Github(
    auth=auth
)

# %%
user = g.get_user()

# %%
repo = user.get_repos()

# %%
for rep in repo:
    print(rep)
# Out:
# Repository(full_name="DevXDividends/Arogyam-Agentic-AI-for-medical-imaging-and-diagnosis")
# Repository(full_name="DevXDividends/Attendance-System-using-Geolocation-and-Browser-Fingerprinting-")
# Repository(full_name="DevXDividends/CodeForge-RCE")
# Repository(full_name="DevXDividends/D.S.A")
# Repository(full_name="DevXDividends/DevXDividends")
# Repository(full_name="DevXDividends/docker-react")
# Repository(full_name="DevXDividends/HERMES-Hidden-and-Encrypted-Recursive-Media-Encoding-System")
# Repository(full_name="DevXDividends/Hospital-Managment-System")
# Repository(full_name="DevXDividends/K-Map-visualiser")
# Repository(full_name="DevXDividends/LanShare")
# Repository(full_name="DevXDividends/LanShareCPP")
# Repository(full_name="DevXDividends/LeetLog-")
# Repository(full_name="DevXDividends/QEMS-system")
# Repository(full_name="DevXDividends/React")
# Repository(full_name="DevXDividends/Resume-Checker")
# Repository(full_name="DevXDividends/Text-to-voice-converter")
# ...

# %%
repo = g.get_repo("DevXDividends/D.S.A")

# %%
dsa_repo = repo.get_contents("")

# %%
dsa_repo
# Out:
# [ContentFile(path="Binary Search"),
#  ContentFile(path="Linked List"),
#  ContentFile(path="README.md"),
#  ContentFile(path="Recursion"),
#  ContentFile(path="Sliding window & Two Pointers"),
#  ContentFile(path="Stack"),
#  ContentFile(path="Strings"),
#  ContentFile(path="Tree"),
#  ContentFile(path="Two Pointer"),
#  ContentFile(path="arrays")]

# %%
data = {}
cnt = 0
for item in dsa_repo:
    if item.type == "dir":
        print(f"\n📂 Entering Folder: {item.name}")
         # Create folder key
        data[item.name] = {}
        folder_contents = repo.get_contents(item.path)
        # print(folder_contents)
        for item_file in folder_contents:
            if item_file.type == "file":
                cnt = cnt+1
                print(f" 📄 File: {item_file.name}")
                code  = item_file.decoded_content.decode("utf-8")
                data[item.name][item_file.name] = code
                preview = "\n".join(code.splitlines()[:3])
                print(f"    Code Preview:\n{preview}\n    ...")
# Out:
# 📂 Entering Folder: Binary Search
#  📄 File: Aggressive-cows.cpp
#     Code Preview:
#  //Brute force TC: O(n×maxDist) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Allocate-Minimum-Pages.cpp
#     Code Preview:
# //Brute force TC:O(n  * sum(arr)  - max(arr)) SC:O(1)
# class Solution {
#   public:
#     ...
#  📄 File: Count of Smaller Numbers After Self.cpp
#     Code Preview:
# // brute force TC:O(n^2) SC:O(n)
# class Solution {
# public:
#     ...
#  📄 File: Find Right Interval.cpp
#     Code Preview:
# // Brute force TC:O(n² + n log n + n) SC:O(3n)
# class Solution {
# public:
#     ...
#  📄 File: Find Smallest Letter Greater Than Target.cpp
#     Code Preview:
# // TC:O(log n) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Find a Peak Element II.cpp
#     Code Preview:
# // brute force TC:O(rows * cols) SC:O(1)
# class Solution {
# public:
#     ...
#  📄 File: Find the Duplicate Number.cpp
#     Code Preview:
# // brute force TC:o(n) SC:O(n)
# ...

# %%
cnt
# Out:
# 174

# %%
with open("dsa_data.json",'w',encoding="utf-8") as file:
    json.dump(data,file,indent=4,ensure_ascii=False)
print("All data saved !")
# Out:
# All data saved !

# %%
print(data["Sliding window & Two Pointers"]["Longest Nice Subarray.cpp"])
# Out:
# //  brute TC:O(n^2) SC:O(1)
# class Solution {
# public:
#     int longestNiceSubarray(vector<int>& nums) {
#         int n = nums.size();
#         int maxLen = 0;
#         for (int i = 0; i < n; i++) {
#             int commulativeBits = 0;
#             for (int j = i; j < n; j++) {
#                 if ((commulativeBits & nums[j]) == 0) {
#                     maxLen = max(maxLen, j - i + 1);
#                     commulativeBits |= nums[j];
#                 } else
#                     break;
#             }
#         }
#         return maxLen;
#     }
# };
# // TC:O(n) SC:O(1)
# class Solution {
# public:
#     int longestNiceSubarray(vector<int>& nums) {
#         int n = nums.size();
#
#         int l = 0;
#         int mask = 0;
#         int ans = 1;
#
#         for (int r = 0; r < n; r++) {
#
#             // Keep shrinking until the current number has
#             // no overlapping bits with the window.
#             while ((mask & nums[r]) != 0) {
# ...

# %%
with open("dsa_data.json",'r',encoding="utf-8") as file:
    d = json.load(file)

# %%
type(d)
# Out:
# dict

# %%
with open("dsa_descriptions.json",'r')as file:
    des = json.load(file)

# %%
des["Aggressive-cows.cpp"].keys()
# Out:
# dict_keys(['title', 'source', 'link', 'description', 'constraints', 'difficulty', 'examples'])

# %%
print(des["Aggressive.cpp"]["title"])
print(des["Aggressive-cows.cpp"]["source"])
print(des["Aggressive-cows.cpp"]["description"])
print(des["Aggressive-cows.cpp"]["examples"])
# Out:
# Aggressive Cows
# GFG
# You are given an array stalls[] of unique integers denoting the positions of stalls. You are also given an integer k which denotes the number of aggressive cows. Assign stalls to k cows such that the minimum distance between any two of them is the maximum possible.
# [{'input': 'stalls[] = [1, 2, 4, 8, 9], k = 3', 'output': '3', 'explanation': 'Place cows at stalls[0]=1, stalls[2]=4, stalls[3]=8. Minimum distance = 3, which is the largest possible.'}, {'input': 'stalls[] = [10, 1, 2, 7, 5], k = 3', 'output': '4', 'explanation': 'Place cows at positions 1, 5, 10. Minimum distance = 4, which is the largest possible.'}]

# %%
def get_problem_metadata(des,problem):
    if problem in des:
        return{
            "title": des[problem]["title"],
            "source":des[problem]["source"],
            "description":des[problem]["description"],
            "examples":des[problem]["examples"],
            "link":des[problem]["link"]
        }
    else:
        return {
            "title": "No data Found !"
        }

# %%
problem = "Allocate-Minimum-Pages.cpp"
get_problem_metadata(des,problem=problem)
# Out:
# {'title': 'Allocate Minimum Pages (Book Allocation)',
#  'source': 'GFG',
#  'description': 'Given an array arr[] where arr[i] represents the number of pages in the i-th book, and k students. Allocate books to k students such that: (1) Each student gets at least one book, (2) Each book is allocated to exactly one student, (3) Books are allocated contiguously. Minimize the maximum number of pages assigned to any student. Return -1 if allocation is not possible.',
#  'examples': [{'input': 'arr[] = [12, 34, 67, 90], k = 2',
#    'output': '113',
#    'explanation': 'Allocation [12, 34, 67] and [90] gives max pages = 113, which is minimum possible.'},
#   {'input': 'arr[] = [15, 17, 20], k = 5',
#    'output': '-1',
#    'explanation': 'Number of students > number of books, allocation not possible.'}],
#  'link': 'https://www.geeksforgeeks.org/problems/allocate-minimum-number-of-pages0937/1'}

# %%
def get_problem(topic,problem_name):
    return {
        "title":des[problem_name]["title"],
        "source":des[problem_name]["source"],
        "description":des[problem_name]["description"],
        "examples":des[problem_name]["examples"],
        "link":des[problem_name]["link"],
        "code":data[topic][problem_name]
    }
get_problem("Binary Search","Allocate-Minimum-Pages.cpp")
# Out:
# {'title': 'Allocate Minimum Pages (Book Allocation)',
#  'source': 'GFG',
#  'description': 'Given an array arr[] where arr[i] represents the number of pages in the i-th book, and k students. Allocate books to k students such that: (1) Each student gets at least one book, (2) Each book is allocated to exactly one student, (3) Books are allocated contiguously. Minimize the maximum number of pages assigned to any student. Return -1 if allocation is not possible.',
#  'examples': [{'input': 'arr[] = [12, 34, 67, 90], k = 2',
#    'output': '113',
#    'explanation': 'Allocation [12, 34, 67] and [90] gives max pages = 113, which is minimum possible.'},
#   {'input': 'arr[] = [15, 17, 20], k = 5',
#    'output': '-1',
#    'explanation': 'Number of students > number of books, allocation not possible.'}],
#  'link': 'https://www.geeksforgeeks.org/problems/allocate-minimum-number-of-pages0937/1',
# ...

# %%
## ALL TOPICS
cur.execute("""
            SELECT DISTINCT topic FROM Problems """)

topic = [row["topic"] for row in cur.fetchall()]
print(topic)
# Out:
# ['arrays', 'Recursion', 'Binary Search', 'Tree', 'Sliding window & Two Pointers', 'Linked List', 'Strings', 'Stack', 'Two Pointer']

# %%
## all problems of a specific topic
cur.execute("""
            SELECT title FROM  problems WHERE topic = 'Binary Search'""")
all_problems = [row["title"] for row in cur.fetchall()]
print(all_problems)
# Out:
# ['Nim Game', 'Split Array Largest Sum', 'Find Right Interval', 'Aggressive Cows', 'Allocate Minimum Pages (Book Allocation)', 'Count of Smaller Numbers After Self', 'Find Smallest Letter Greater Than Target', 'Find a Peak Element II', 'Find the Duplicate Number', 'Find Minimum in Rotated Sorted Array II', 'First and Last Occurrences in a Sorted Array', 'First Bad Version', 'H-Index II', 'Heaters', 'Intersection of Two Arrays', 'K-diff Pairs in an Array', 'K-th Element of Two Sorted Arrays', 'Search a 2D Matrix', 'Kth Smallest Element in a Sorted Matrix', 'Kth Smallest Product of Two Sorted Arrays', 'Kth Missing Positive Number', 'Median in a Row-wise Sorted Matrix', 'Median of Two Sorted Arrays', 'Minimize Maximum Distance to Gas Station', ' Number of occurrence', 'Row With Maximum Ones', ' Search in Rotated Sorted Array', 'Sqrt(x)']

# %%
## Problem Data of specific problem
cur.execute("""
            SELECT 
	title,source,description,examples,link,constraints,difficulty,editorial_code 
			FROM problems 
	WHERE topic  = 'Binary Search' AND title = 'Aggressive Cows'  
	""").fetchall()
# Out:
# [{'title': 'Aggressive Cows',
#   'source': 'GFG',
#   'description': 'You are given an array stalls[] of unique integers denoting the positions of stalls. You are also given an integer k which denotes the number of aggressive cows. Assign stalls to k cows such that the minimum distance between any two of them is the maximum possible.',
#   'examples': [{'input': 'stalls[] = [1, 2, 4, 8, 9], k = 3',
#     'output': '3',
#     'explanation': 'Place cows at stalls[0]=1, stalls[2]=4, stalls[3]=8. Minimum distance = 3, which is the largest possible.'},
#    {'input': 'stalls[] = [10, 1, 2, 7, 5], k = 3',
#     'output': '4',
#     'explanation': 'Place cows at positions 1, 5, 10. Minimum distance = 4, which is the largest possible.'}],
#   'link': 'https://www.geeksforgeeks.org/problems/aggressive-cows/0',
#   'constraints': ['2 ≤ arr.size() ≤ 10^6',
#    '0 ≤ arr[i] ≤ 10^8',
#    '2 ≤ k ≤ arr.size()'],
#   'difficulty': 'Medium',
# ...
