# %% [markdown]
# this file is used to find all the problems with no description and vice versa

# %%
import  json

# %%
with open("../dsa_data.json","r",encoding="utf-8") as file:
    data = json.load(file)
with open("../dsa_descriptions.json","r") as file:
    description = json.load(file)
    
    
if data and description :
    print("data loaded 👍")
# Out:
# data loaded 👍

# %%
missing_descriptions = []
for topic in data:
    for problem in data[topic]:
        if problem not in description:
            missing_descriptions.append((topic,problem))
            
print("Problems with missing description")
cnt = 0
for topic,problem in missing_descriptions:
    cnt = cnt+1
    print(f"{cnt}. {topic}: {problem}")
# Out:
# Problems with missing description
# 1. Binary Search: Find Right Interval.cpp
# 2. Binary Search: Number of occurrence.cpp
# 3. Binary Search: Search in Rotated Sorted Array.cpp
# 4. Sliding window & Two Pointers: Binary Subarrays With Sum
# 5. Sliding window & Two Pointers: Count Number of Nice Subarrays.cpp
# 6. Sliding window & Two Pointers: Fruit Into Baskets.cpp
# 7. Sliding window & Two Pointers: Indexes of Subarray Sum.cpp
# 8. Sliding window & Two Pointers: Longest Repeating Character Replacement.cpp
# 9. Sliding window & Two Pointers: Longest Substring With At Most K Distinct Characters.cpp
# 10. Sliding window & Two Pointers: Longest Substring with At Least K Repeating Characters .cpp
# 11. Sliding window & Two Pointers: Longest Substring with K Uniques.cpp
# 12. Sliding window & Two Pointers: Longest substring without repeating characters.cpp
# 13. Sliding window & Two Pointers: Max Consecutive Ones III.cpp
# 14. Sliding window & Two Pointers: Max Sum Subarray of size K.cpp
# 15. Sliding window & Two Pointers: Maximum Points You Can Obtain from Cards.cpp
# 16. Sliding window & Two Pointers: Number of Substrings Containing All Three Characters.cpp
# 17. Sliding window & Two Pointers: ubarrays with K Different Integers.cpp
# 18. Stack: LRU Cache.cpp
# 19. Stack: Sliding Window Maximum.cpp
# 20. arrays: CSES - Apartments.cpp
